# %% [markdown]
# <a href="https://colab.research.google.com/github/won462/2026bda/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

plt.suptitle('전체 제목', fontsize=4,y=1.02)

plt.subplot(2,3,1)
plt.plot([1,4,9,16])
plt.title('제곱수')

plt.subplot(2,3,6)
plt.plot([1,2,3,4])
plt.title('선형')

plt.subplot(2,3,2) # Missing argument added here
plt.plot([6,5,2,1])
plt.title('감소')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1014/169084191.py:17: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/169084191.py:17: UserWarning: Glyph 44273 (\N{HANGUL SYLLABLE GOB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/169084191.py:17: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/169084191.py:17: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/169084191.py:17: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/169084191.py:17: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2,3,figsize=(7,4))
fig.set_size_inches(6,3)

ax[0,1].plot([1,4,9,16])
ax[1,0].plot([1,2,3,4])
ax[1,2].plot([6,5,2,])

fig.suptitle('전체 제목',fontsize=14,fontweight='bold')

ax[0,0].set_title('(0,0) 빈 플롯')
ax[0,0].set_title('(0,1) 제곱수')
ax[0,0].set_title('(0,2) 빈 플롯')
ax[0,0].set_title('(1,0) 선형')
ax[0,0].set_title('(1,1) 빈 플롯')
ax[0,0].set_title('(1,2) 감소')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1014/1109219651.py:18: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/1109219651.py:18: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/1109219651.py:18: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/1109219651.py:18: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/1109219651.py:18: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/1109219651.py:18: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(6,4))

ax1 = fig.add_subplot(231)
ax1.plot ([1,4,9,16])
ax1.set_title('제곱수')

ax2 = fig.add_subplot(233)
ax2.plot ([1,2,3,4])
ax2.set_title('선형')

ax3 = fig.add_subplot(235)
ax3.plot ([6,5,2,1])
ax3.set_title('감소')

fig.suptitle('전체 제목',fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1014/2081759983.py:18: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/2081759983.py:18: UserWarning: Glyph 44273 (\N{HANGUL SYLLABLE GOB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/2081759983.py:18: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/2081759983.py:18: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/2081759983.py:18: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1014/2081759983.py:18: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
import pandas as pd
import numpy as np

age = pd.Series([9,17,32,45,65,98], index=list('abcdef'),name='age')
age
# Out:
# a     9
# b    17
# c    32
# d    45
# e    65
# f    98
# Name: age, dtype: int64

# %%
import pandas as pd
s = pd.Series([3,6,-3,0,-4,8,-7])
s
# Out:
# 0    3
# 1    6
# 2   -3
# 3    0
# 4   -4
# 5    8
# 6   -7
# dtype: int64

# %%
courses = pd.Series(["Spark","PySpark","Hadoop"],name='courses')
courses
# Out:
# 0      Spark
# 1    PySpark
# 2     Hadoop
# Name: courses, dtype: object

# %%
fees = pd.Series([250000,300000,200000],name='fees')
fees
# Out:
# 0    250000
# 1    300000
# 2    200000
# Name: fees, dtype: int64

# %%
df = pd.DataFrame({courses.name:courses,fees.name:fees})
df
# Out:
#    courses    fees
# 0    Spark  250000
# 1  PySpark  300000
# 2   Hadoop  200000
